# %% [markdown]
# ## Análise dos antecedentes dos congressistas brasileiros pelo olhar ambiental
#
# ### A base das análises é a planilha 'políticos_check_trabalho.csv' que foi montada a partir do cruzamento de várias fontes de dados como http://www.politicos.org.br/processos; STF; tribunais estaduais e eleitorais para avaliar os congressistas sobre processos cíveis, criminais, eleitorais em que são réus e condenados.
#
# #### A primeira parte da análise buscou processos por dano ambiental.

# %%
import pandas as pd

# %%
ambiente = pd.read_csv('politicos_check_trabalho.csv')

# %%
ambiente.head()
# Out:
#                     Nome             cargo partido estado  \
# 0           Acir Gurgacz           Senador     PDT     RO
# 1  Adalberto Cavalcanti   Deputado Federal  AVANTE     PE
# 2  Adalberto Cavalcanti   Deputado Federal  AVANTE     PE
# 3  Adalberto Cavalcanti   Deputado Federal  AVANTE     PE
# 4  Adalberto Cavalcanti   Deputado Federal  AVANTE     PE
#
#                    ocorrencia  \
# 0                 Estelionato
# 1  Improbidade Administrativa
# 2  Improbidade Administrativa
# 3              Dano ao Erário
# 4  Improbidade Administrativa
#
#                                            descricao                  status  \
# 0  Crime de Estelionato e crimes contra o Sistema...   Em andamento- Recurso
# 1  Emprego irregular de verbas ou rendas públicas...  Em andamento - Recurso
# 2                         Improbidade Administrativa            Em Andamento
# 3                         Improbidade Administrativa          Dano ao Erário
# ...

# %%
ambiente.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1294 entries, 0 to 1293
# Data columns (total 8 columns):
# Nome          1294 non-null object
# cargo         1294 non-null object
# partido       1294 non-null object
# estado        1294 non-null object
# ocorrencia    1294 non-null object
# descricao     1294 non-null object
# status        1261 non-null object
# processo      1261 non-null object
# dtypes: object(8)
# memory usage: 81.0+ KB

# %%
ambiente[ambiente.Nome == 'Macedo']
# Out:
#        Nome             cargo partido estado      ocorrencia  \
# 628  Macedo  Deputado Federal      PP     CE  Dano Ambiental
# 629  Macedo  Deputado Federal      PP     CE  Dano Ambiental
# 630  Macedo  Deputado Federal      PP     CE  Dano Ambiental
#
#                                              descricao              status  \
# 628  Foi autuado pelo Ministério Público Federal po...  Segredo de Justiça
# 629    É alvo de ação civil pública por Dano Ambiental  Segredo de Justiça
# 630  Acusado de construir imóvel residencial  em ár...               Findo
#
#                                               processo
# 628  0000266-74.2008.4.05.8101 - TRF - 5 (http://ww...
# 629  0006293-66.2014.4.05.8100 - TRF - 5 (http://ww...
# 630  980 - STF (http://portal.stf.jus.br/processos/...

# %% [markdown]
# #### 20 processos por danos ambientais foram encontrados, a maioria por transformar áreas públicas, de preservação ambiental e áreas em particulares, construindo edificações irregulares e degradando o ambiente ao redor. A maior parte dos processos termina em acordo com pagamento de multas ambientais e/ou a obrigação de reparar o dano, o que quase nunca acontece.

# %%
ambiente[ambiente.ocorrencia == 'Dano Ambiental']
# Out:
#                       Nome             cargo partido estado      ocorrencia  \
# 5     Adelmo Carneiro Leão  Deputado Federal      PT     MG  Dano Ambiental
# 171       Augusto Coutinho  Deputado Federal      SD     PE  Dano Ambiental
# 172       Augusto Coutinho  Deputado Federal      SD     PE  Dano Ambiental
# 173       Augusto Coutinho  Deputado Federal      SD     PE  Dano Ambiental
# 209         Carlos Bezerra  Deputado Federal     MDB     MT  Dano Ambiental
# 281         Dâmina Pereira  Deputado Federal    PODE     MG  Dano Ambiental
# 326           Edmar Arruda  Deputado Federal     PSD     PR  Dano Ambiental
# 483           Irajá Abreu   Deputado Federal     PSD     TO  Dano Ambiental
# 507        Jandira Feghali  Deputado Federal   PCdoB     RJ  Dano Ambiental
# 563        João Paulo Papa  Deputado Federal    PSDB     SP  Dano Ambiental
# 628                 Macedo  Deputado Federal      PP     CE  Dano Ambiental
# ...

# %% [markdown]
# #### Atualização dos deputados que cometeram crime ambiental.

# %%
x = ['Washigton Reis', 'Deputado Federal', 'MDB', 'RJ', 'Dano Ambiental', 
     'Réu por crimes contra o meio ambiente pela construção, instalação e funcionamento de estabelecimentos poluidores, capazes de causar degradação ambiental, sem prévio licenciamento ambiental',
     'Em Andamento', 'STF - http://portal.stf.jus.br/processos/detalhe.asp?incidente=4094146']  
#fonte Ruralômetro

# %%
x
# Out:
# ['Washigton Reis',
#  'Deputado Federal',
#  'MDB',
#  'RJ',
#  'Dano Ambiental',
#  'Réu por crimes contra o meio ambiente pela construção, instalação e funcionamento de estabelecimentos poluidores, capazes de causar degradação ambiental, sem prévio licenciamento ambiental',
#  'Em Andamento',
#  'STF - http://portal.stf.jus.br/processos/detalhe.asp?incidente=4094146']

# %%
crime_ambiental = ambiente[ambiente.ocorrencia == 'Dano Ambiental']

# %%
crime_ambiental['estado'].value_counts()
# Out:
# SP    4
# PE    3
# CE    3
# MG    3
# PR    2
# TO    2
# RJ    1
# MT    1
# AL    1
# Name: estado, dtype: int64

# %%
crime_ambiental['partido'].value_counts()
# Out:
# SD       3
# MDB      3
# PP       3
# PSD      2
# PSDB     2
# PT       2
# PDT      1
# PR       1
# PCdoB    1
# PTB      1
# PODE     1
# Name: partido, dtype: int64

# %%
crime_ambiental.groupby('partido')['Nome'].value_counts()
# Out:
# partido  Nome
# MDB      Carlos Bezerra          1
#          Newton Cardoso Jr       1
#          Renan Calheiros         1
# PCdoB    Jandira Feghali         1
# PDT      Kátia Abreu             1
# PODE     Dâmina Pereira          1
# PP       Macedo                  3
# PR       Marcio Alvino           1
# PSD      Edmar Arruda            1
#          Irajá Abreu             1
# PSDB     João Paulo Papa         1
#          Rossoni                 1
# PT       Adelmo Carneiro Leão    1
#          Paulo Teixeira          1
# PTB      Nelson Marquezelli      1
# SD       Augusto Coutinho        3
# Name: Nome, dtype: int64

# %%
crime_ambiental.groupby('Nome')['ocorrencia'].value_counts()
# Out:
# Nome                  ocorrencia
# Adelmo Carneiro Leão  Dano Ambiental    1
# Augusto Coutinho      Dano Ambiental    3
# Carlos Bezerra        Dano Ambiental    1
# Dâmina Pereira        Dano Ambiental    1
# Edmar Arruda          Dano Ambiental    1
# Irajá Abreu           Dano Ambiental    1
# Jandira Feghali       Dano Ambiental    1
# João Paulo Papa       Dano Ambiental    1
# Kátia Abreu           Dano Ambiental    1
# Macedo                Dano Ambiental    3
# Marcio Alvino         Dano Ambiental    1
# Nelson Marquezelli    Dano Ambiental    1
# Newton Cardoso Jr     Dano Ambiental    1
# Paulo Teixeira        Dano Ambiental    1
# Renan Calheiros       Dano Ambiental    1
# Rossoni               Dano Ambiental    1
# Name: ocorrencia, dtype: int64

# %% [markdown]
# #### Com informações do relatório da Amazon Watch acusando seis deputados da bancada ruralista de crimes ambientais, sociais e econômicos relacionados à Amazônia brasileira. Cinco deles são candidatos às eleições 2018. São apontados Adilton Sachetti (PRB/MT), Alfredo Kaefer (PP/PR), Dilceu Sperafico (PP/PR), Nelson Marquezelli (PTB/SP),Adilton Sachetti (PRB/MT) e o deputados estadual Jorge Amanajás (PPS/AP) que não faz parte dessa análise.
#
# #### Fonte: https://jornalggn.com.br/sites/default/files/documentos/2018-complicity-in-destruction.pdf

# %%
ambiente[ambiente.Nome == 'Adilton Sachetti']
# Out:
#                 Nome             cargo partido estado  \
# 10  Adilton Sachetti  Deputado Federal     PRB     MT
# 11  Adilton Sachetti  Deputado Federal     PRB     MT
# 12  Adilton Sachetti  Deputado Federal     PRB     MT
# 13  Adilton Sachetti  Deputado Federal     PRB     MT
# 14  Adilton Sachetti  Deputado Federal     PRB     MT
# 15  Adilton Sachetti  Deputado Federal     PRB     MT
# 16  Adilton Sachetti  Deputado Federal     PRB     MT
# 17  Adilton Sachetti  Deputado Federal     PRB     MT
# 18  Adilton Sachetti  Deputado Federal     PRB     MT
# 19  Adilton Sachetti  Deputado Federal     PRB     MT
# 20  Adilton Sachetti  Deputado Federal     PRB     MT
# 21  Adilton Sachetti  Deputado Federal     PRB     MT
# 22  Adilton Sachetti  Deputado Federal     PRB     MT
# 23  Adilton Sachetti  Deputado Federal     PRB     MT
#
#                           ocorrencia  \
# 10        Improbidade Administrativa
# 11                   Crime Eleitoral
# ...

# %%
adilton = ambiente[ambiente.Nome == 'Adilton Sachetti']

# %%
adilton.ocorrencia.value_counts()
# Out:
# Crime de Responsabilidade           3
# Dano ao Erário                      2
# Crime contra a Lei de Licitações    2
# Improbidade Administrativa          2
# Apropriação Indébita                2
# Crime Eleitoral                     1
# Enriquecimento Ilícito              1
# Apropriação indébita                1
# Name: ocorrencia, dtype: int64

# %%
adilton.Nome.count()
# Out:
# 14

# %%
#O ex-prefeito é acusado de omissão ao permitir que seu secretário municipal de Desenvolvimento Econômico se apropriasse irregularmente de lotes públicos no Distrito Industrial de Rondonópolis por meio de empresa fictícia, o que causou prejuízo aos cofres públicos.
#A acusação alega que foram transferidos dois lotes públicos à Construtora Égide sem realização de licitação, causando prejuízo aos cofres públicos.
#A acusação alega que foram transferidos lotes públicos às empresas Sachet & Fagundes Ltda. e Agropecuária B&Q S.A. sem procedimento licitatório, enriquecendo-as ilicitamente e causando prejuízo aos cofres públicos.

# %%
ambiente[ambiente.Nome == 'Nelson Marquezelli']   #Junto com Companhia Siderúrgica Pitangui e Rio Rancho Agropecuária S/A, 
                                                  #de propriedade de sua família, o deputado é réu por falsidade ideológica e por crimes contra o meio ambiente.
# Out:
#                     Nome             cargo partido estado  \
# 1000  Nelson Marquezelli  Deputado Federal     PTB     SP
# 1001  Nelson Marquezelli  Deputado Federal     PTB     SP
# 1002  Nelson Marquezelli  Deputado Federal     PTB     SP
# 1003  Nelson Marquezelli  Deputado Federal     PTB     SP
#
#                       ocorrencia  \
# 1000             Crime Eleitoral
# 1001             Crime Eleitoral
# 1002              Dano Ambiental
# 1003  Improbidade Administrativa
#
#                                               descricao  \
# 1000  Contas de candidato a deputado federal desapro...
# 1001  Contas de campanha eleitoral para deputado fed...
# 1002  É réu em ação civil pública por Dano Ambiental...
# 1003  É réu em ação civil pública por Improbidade Ad...
#
#                       status  \
# 1000                 Julgado
# 1001                 Julgado
# 1002  Em andamento / Recurso
# 1003  Em andamento / Recurso
#
#                                                processo
# ...

# %%
ambiente[ambiente.Nome == 'Gabriel Guimarães']      # quem mais recebeu doação eleitoral direta e indireta de empresas flagradas por trabalho escravo.
# Out:
# Empty DataFrame
# Columns: [Nome, cargo, partido, estado, ocorrencia, descricao, status, processo]
# Index: []

# %%
ambiente[ambiente.Nome == 'Alfredo Kaefer']
# Out:
#                Nome             cargo partido estado  \
# 490  Alfredo Kaefer  Deputado Federal      PP     PR
# 491  Alfredo Kaefer  Deputado Federal      PP     PR
# 492  Alfredo Kaefer  Deputado Federal      PP     PR
# 493  Alfredo Kaefer  Deputado Federal      PP     PR
# 494  Alfredo Kaefer  Deputado Federal      PP     PR
# 495  Alfredo Kaefer  Deputado Federal      PP     PR
#
#                             ocorrencia  \
# 490                Crimes Falimentares
# 491  Crimes contra a Ordem Tributária.
# 492                Lavagem de Dinheiro
# 493  Crimes contra a Ordem Tributária.
# 494  Crime contra o Patrimônio Público
# 495              Formação de Quadrilha
#
#                                              descricao        status  \
# 490                                Crimes Falimentares  Em andamento
# 491                  Crimes contra a Ordem Tributária.  Em andamento
# 492  Crimes de "Lavagem" ou Ocultação de Bens, Dire...  Em andamento
# ...

# %%
alfredo = ambiente[ambiente.Nome == 'Alfredo Kaefer']

# %%
alfredo.Nome.count()
# Out:
# 6

# %%
ambiente[ambiente.Nome == 'Sidney Rosa']
# Out:
# Empty DataFrame
# Columns: [Nome, cargo, partido, estado, ocorrencia, descricao, status, processo]
# Index: []

# %% [markdown]
# #### Cruzamento e análise de dados da planilha bancadas da camara disponibilizada em matéria da Agencia Publica
# #### Fonte: https://apublica.org/2016/02/truco-as-bancadas-da-camara/

# %%
agro = pd.read_csv('bancadas_camara.csv')

# %%
agro.head()
# Out:
#                Nome partido estado  mandatos  Situação  Evangélica  Ruralista  \
# 0   Alexandre Leite     DEM     SP       2.0  Reeleito         NaN        1.0
# 1     Carlos Melles     DEM     MG       6.0  Reeleito         1.0        1.0
# 2    Cláudio Cajado     DEM     BA       6.0  Reeleito         NaN        1.0
# 3      Efraim Filho     DEM     PB       3.0  Reeleito         NaN        1.0
# 4  Eli Corrêa Filho     DEM     SP       2.0  Reeleito         NaN        1.0
#
#    Bala  Sindical  Direitos Humanos  Mineração  Empresarial  Parentes  Saúde  \
# 0   NaN       NaN               NaN        NaN          1.0       1.0    NaN
# 1   NaN       NaN               NaN        NaN          1.0       1.0    NaN
# 2   NaN       NaN               NaN        1.0          1.0       1.0    NaN
# 3   1.0       NaN               NaN        NaN          NaN       1.0    NaN
# 4   NaN       NaN               NaN        NaN          1.0       NaN    NaN
#
# ...

# %%
agro.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 513 entries, 0 to 512
# Data columns (total 17 columns):
# Nome                         513 non-null object
# partido                      512 non-null object
# estado                       512 non-null object
# mandatos                     512 non-null float64
# Situação                     335 non-null object
# Evangélica                   196 non-null float64
# Ruralista                    207 non-null float64
# Bala                         35 non-null float64
# Sindical                     44 non-null float64
# Direitos Humanos             25 non-null float64
# Mineração                    24 non-null float64
# Empresarial                  209 non-null float64
# Parentes                     239 non-null float64
# Saúde                        22 non-null float64
# Bola                         15 non-null float64
# Empreiteiras/construtoras    226 non-null float64
# Total de bancadas            512 non-null float64
# ...

# %%
agro['Ruralista'].count()
# Out:
# 207

# %%
agro[(agro['Ruralista'] == 1)]
# Out:
#                        Nome partido estado  mandatos  Situação  Evangélica  \
# 0           Alexandre Leite     DEM     SP       2.0  Reeleito         NaN
# 1             Carlos Melles     DEM     MG       6.0  Reeleito         1.0
# 2            Cláudio Cajado     DEM     BA       6.0  Reeleito         NaN
# 3              Efraim Filho     DEM     PB       3.0  Reeleito         NaN
# 4          Eli Corrêa Filho     DEM     SP       2.0  Reeleito         NaN
# 7               Hélio Leite     DEM     PA       1.0       NaN         1.0
# 10                 Mandetta     DEM     MS       2.0  Reeleito         NaN
# 13           Misael Varella     DEM     MG       1.0      Novo         NaN
# 15           Ônyx Lorenzoni     DEM     RS       4.0  Reeleito         NaN
# 30             Afonso Motta     PDT     RS       2.0       NaN         NaN
# 31                Dagoberto     PDT     MS       2.0       NaN         NaN
# ...

# %%
rural = agro[(agro['Ruralista'] == 1)]

# %%
rural.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 206 entries, 0 to 510
# Data columns (total 17 columns):
# Nome                         206 non-null object
# partido                      206 non-null object
# estado                       206 non-null object
# mandatos                     206 non-null float64
# Situação                     149 non-null object
# Evangélica                   83 non-null float64
# Ruralista                    206 non-null float64
# Bala                         17 non-null float64
# Sindical                     7 non-null float64
# Direitos Humanos             0 non-null float64
# Mineração                    18 non-null float64
# Empresarial                  113 non-null float64
# Parentes                     105 non-null float64
# Saúde                        5 non-null float64
# Bola                         7 non-null float64
# Empreiteiras/construtoras    91 non-null float64
# Total de bancadas            206 non-null float64
# ...

# %% [markdown]
# #### Segundo esses dados 'http://bit.ly/2Q9Rr4h' a bancada ruralista na Câmara dos Deputados é composta de 206 integrantes.

# %%
rural.Situação.value_counts()
# Out:
# Reeleito    113
# Novo         31
# Suplente      5
# Name: Situação, dtype: int64

# %%
rural.Nome
# Out:
# 0             Alexandre Leite
# 1               Carlos Melles
# 2              Cláudio Cajado
# 3                Efraim Filho
# 4            Eli Corrêa Filho
# 7                 Hélio Leite
# 10                   Mandetta
# 13             Misael Varella
# 15             Ônyx Lorenzoni
# 30               Afonso Motta
# 31                  Dagoberto
# 33      Félix Mendonça Júnior
# 34              Flávia Morais
# 36            Giovani Cherini
# 40             Mário Heringer
# 42               Roberto Góes
# 44             Sergio Vidigal
# 46             Weverton Rocha
# 48               André Fufuca
# 51               Diego Garcia
# 52              Kaio Maniçoba
# 53                Marcelo Aro
# 54       Abel Mesquita Júnior
# 58             Assis do Couto
# 60     Carlos Henrique Gaguim
# 62              Domingos Neto
# 63              Fábio Ramalho
# 65            Juscelino Filho
# 68     Marcelo Álvaro Antônio
# 72           Valtenir Pereira
#                 ...
# ...

# %% [markdown]
# #### A maior bancada é do PMDB(MDB), depois PP, PSDB, etc.

# %%
rural.partido.value_counts()
# Out:
# PMDB    45
# PP      19
# PSDB    18
# PSD     17
# PR      16
# PSB     13
# SD      12
# DEM      9
# PMB      9
# PDT      9
# PTB      9
# PRB      7
# PSC      6
# PT       6
# PHS      3
# Pros     2
# PPS      2
# PV       2
# PMN      1
# PEN      1
# Name: partido, dtype: int64

# %% [markdown]
# #### Os estados dos ruralistas, todos com maior concentração em Minas Gerais

# %%
rural.estado.value_counts()
# Out:
# MG    30
# PR    20
# RS    15
# SP    14
# RJ    12
# GO    11
# BA    10
# PA    10
# SC    10
# MT     7
# TO     6
# PB     6
# CE     6
# MS     6
# ES     6
# MA     5
# AC     5
# RO     4
# RN     4
# AL     3
# AP     3
# DF     3
# PI     3
# RR     2
# SE     2
# PE     2
# AM     1
# Name: estado, dtype: int64

# %% [markdown]
# #### Junção das planilhas ruralistas com a planilha de processos judiciais.

# %%
merged = pd.merge(ambiente, rural, on='Nome')

# %%
merged.head()
# Out:
#                Nome             cargo partido_x estado_x  \
# 0  Adilton Sachetti  Deputado Federal       PRB       MT
# 1  Adilton Sachetti  Deputado Federal       PRB       MT
# 2  Adilton Sachetti  Deputado Federal       PRB       MT
# 3  Adilton Sachetti  Deputado Federal       PRB       MT
# 4  Adilton Sachetti  Deputado Federal       PRB       MT
#
#                    ocorrencia  \
# 0  Improbidade Administrativa
# 1             Crime Eleitoral
# 2   Crime de Responsabilidade
# 3   Crime de Responsabilidade
# 4   Crime de Responsabilidade
#
#                                            descricao  \
# 0  O parlamentar é acusado de realiza repasses ir...
# 1         Falsidade Ideológica para fins eleitorais.
# 2                          Crime de Responsabilidade
# 3  Crime de Responsabilidade enquadrado na Lei de...
# 4                          Crime de Responsabilidade
#
#                            status  \
# 0                    Em Andamento
# ...

# %%
merged.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 385 entries, 0 to 384
# Data columns (total 24 columns):
# Nome                         385 non-null object
# cargo                        385 non-null object
# partido_x                    385 non-null object
# estado_x                     385 non-null object
# ocorrencia                   385 non-null object
# descricao                    385 non-null object
# status                       384 non-null object
# processo                     384 non-null object
# partido_y                    385 non-null object
# estado_y                     385 non-null object
# mandatos                     385 non-null float64
# Situação                     331 non-null object
# Evangélica                   151 non-null float64
# Ruralista                    385 non-null float64
# Bala                         20 non-null float64
# Sindical                     4 non-null float64
# Direitos Humanos             0 non-null float64
# ...

# %% [markdown]
# #### Noventa deputados da bancada ruralista na Câmara são réus e/ou condenados em 385 processos judiciais.

# %%
merged.Ruralista.value_counts()
# Out:
# 1.0    385
# Name: Ruralista, dtype: int64

# %%
merged.groupby(["Nome", "Ruralista"]).ocorrencia.sum().reset_index().sort_values("ocorrencia", ascending=False)
# Out:
#                       Nome  Ruralista  \
# 60                Mandetta        1.0
# 7             Aníbal Gomes        1.0
# 87      Wellington Roberto        1.0
# 86        Valtenir Pereira        1.0
# 46             Jozi Araújo        1.0
# 9              Arthur Lira        1.0
# 69           Nelson Meurer        1.0
# 74             Paulo Feijó        1.0
# 10    Arthur Oliveira Maia        1.0
# 1           Aelton Freitas        1.0
# 61  Marcelo Álvaro Antônio        1.0
# 67            Milton Monti        1.0
# 42          Jorginho Mello        1.0
# 41             Jony Marcos        1.0
# 24           Daniel Vilela        1.0
# 52        Leonardo Quintão        1.0
# 53         Lincoln Portela        1.0
# 48          João Rodrigues        1.0
# 21          Célio Silveira        1.0
# 65            Marx Beltrão        1.0
# 0         Adilton Sachetti        1.0
# 83          Simone Morgado        1.0
# 19          Celso Maldaner        1.0
# ...

# %%
crime_rural = merged.groupby(["Nome", "Ruralista"]).ocorrencia.sum().reset_index().sort_values("ocorrencia", ascending=False)

# %%
crime_rural.head()                    #deputados com processos da bancada ruralista
# Out:
#                   Nome  Ruralista  \
# 60            Mandetta        1.0
# 7         Aníbal Gomes        1.0
# 87  Wellington Roberto        1.0
# 86    Valtenir Pereira        1.0
# 46         Jozi Araújo        1.0
#
#                                            ocorrencia
# 60  Tráfico de InfluênciaImprobidade Administrativ...
# 7   Sonegação de impostosCrime de Responsabilidade...
# 87                            Reivindicação de Imóvel
# 86  PeculatoCrime EleitoralCrime EleitoralCrime El...
# 46                                     Lesão Corporal

# %%
crime_rural.Nome.count()
# Out:
# 90

# %%
crime_rural = merged.groupby(["Nome", "Ruralista"]).ocorrencia.max().reset_index().sort_values("ocorrencia")

# %%
crime_rural
# Out:
#                       Nome  Ruralista  \
# 33           Evandro Roman        1.0
# 80                   Rocha        1.0
# 47             João Campos        1.0
# 63          Marcus Pestana        1.0
# 75         Paulo Magalhães        1.0
# 36     Gilberto Nascimento        1.0
# 49             Júlio Cesar        1.0
# 37         Guilherme Mussi        1.0
# 58          Lázaro Botelho        1.0
# 12             Benito Gama        1.0
# 56            Luiz Cláudio        1.0
# 54           Luciano Ducci        1.0
# 4          Alexandre Leite        1.0
# 3            Alex Canziani        1.0
# 84           Ságuas Moraes        1.0
# 79        Roberto Balestra        1.0
# 34        Genecias Noronha        1.0
# 88          Weverton Rocha        1.0
# 35         Geraldo Resende        1.0
# 72             Osmar Terra        1.0
# 31        Eli Corrêa Filho        1.0
# 20            Cleber Verde        1.0
# 8            Arnaldo Jordy        1.0
# ...

# %%
crime_rural[crime_rural.Nome == 'Adilton Sachetti']
# Out:
#                Nome  Ruralista                  ocorrencia
# 0  Adilton Sachetti        1.0  Improbidade Administrativa

# %%
crime_rural[crime_rural.Nome == 'Alfredo Kaefer']
# Out:
#              Nome  Ruralista           ocorrencia
# 5  Alfredo Kaefer        1.0  Lavagem de Dinheiro

# %%
crime_rural[crime_rural.Nome == 'Dilceu Sperafico']
# Out:
# Empty DataFrame
# Columns: [Nome, Ruralista, ocorrencia]
# Index: []

# %%
crime_rural[crime_rural.Nome == 'Nelson Marquezelli']
# Out:
#                   Nome  Ruralista                  ocorrencia
# 68  Nelson Marquezelli        1.0  Improbidade Administrativa

# %%
crime_rural[crime_rural.Nome == 'Jorge Amanajás']
# Out:
# Empty DataFrame
# Columns: [Nome, Ruralista, ocorrencia]
# Index: []

# %%
crime_rural[crime_rural.Nome == 'Washigton Reis']
# Out:
# Empty DataFrame
# Columns: [Nome, Ruralista, ocorrencia]
# Index: []

# %%
crime_rural[crime_rural.Nome == 'Gabriel Guimarães']
# Out:
# Empty DataFrame
# Columns: [Nome, Ruralista, ocorrencia]
# Index: []

# %%
crime_rural[crime_rural. Nome == 'Evandro Roman']
# Out:
#              Nome  Ruralista      ocorrencia
# 33  Evandro Roman        1.0  Abuso de Poder

# %% [markdown]
# #### Cruzando mais dados, projetos de lei ambientais.
# ###### Fonte.: https://ruralometro.reporterbrasil.org.br/metodologia#download

# %%
contra = pd.read_csv('projetos_ambiente.csv')

# %%
contra.head()
# Out:
#         Projeto                     Nome          Autor  \
# 0   PL 334/2015  Marco Tebaldi (PSDB/SC)  MARCO TEBALDI
# 1  PL 3200/2015    Covatti Filho (PP/RS)  COVATTI FILHO
# 2  PL 1216/2015    Covatti Filho (PP/RS)  COVATTI FILHO
# 3  PL 3615/2012       Padre João (PT/MG)     PADRE JOÃO
# 4  PL 6442/2016  Nilson Leitão (PSDB/MT)  NILSON LEITÃO
#
#                                               Ementa  \
# 0  Altera o art. 4º da Lei nº 1283 de 18 de dezem...
# 1  Dispõe sobre a Política Nacional de Defensivos...
# 2  Regulamenta o artigo 231 da Constituição Feder...
# 3  Acrescenta dispositivo à Lei nº 7.802, de 11 d...
# 4  Institui normas reguladoras do trabalho rural ...
#
#                                              Assunto  Indicado_por  \
# 0  Permite que estados e municípios realizem insp...        Contag
# 1  Cria outro nome para agrotóxicos e facilita a ...        Contag
# 2  Cria mais etapas para a demarcação de áreas in...          Apib
# ...

# %%
contra.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 131 entries, 0 to 130
# Data columns (total 12 columns):
# Projeto                 131 non-null object
# Nome                    131 non-null object
# Autor                   131 non-null object
# Ementa                  36 non-null object
# Assunto                 131 non-null object
# Indicado_por            123 non-null object
# Quem_avaliou            131 non-null object
# Qual_avaliacao          131 non-null object
# Estado                  131 non-null object
# CPF                     131 non-null int64
# Partido_eleicao         131 non-null object
# Nome_urna_tramitacao    131 non-null object
# dtypes: int64(1), object(11)
# memory usage: 12.4+ KB

# %%
contra.Assunto.value_counts()
# Out:
# Altera processo de demarcação de terras indígenas                                                                                                               8
# Cria plano de sustentabilidade ambiental para municípios de até 100 mil habitantes                                                                              4
# Cria CPI para investigar atuação da Funai e do Incra                                                                                                            4
# Permite às comunidades indígenas praticar e comercializar atividades agropecuárias e florestais em suas terras                                                  2
# Inclui novos procedimentos à Política Nacional sobre Mudança do Clima para redução dos gases de efeito estufa                                                   2
# Cria mais etapas para a demarcação de áreas indígenas                                                                                                           2
# ...

# %%
contra[contra.Nome == 'Adilton Sachetti']
# Out:
# Empty DataFrame
# Columns: [Projeto, Nome, Autor, Ementa, Assunto, Indicado_por, Quem_avaliou, Qual_avaliacao, Estado, CPF, Partido_eleicao, Nome_urna_tramitacao]
# Index: []

# %%
contra.Qual_avaliacao.value_counts()
# Out:
# Desfavorável    87
# Favorável       44
# Name: Qual_avaliacao, dtype: int64

# %%
contra[contra.Qual_avaliacao == 'Desfavorável'].head()
# Out:
#          Projeto                     Nome          Autor  \
# 1   PL 3200/2015    Covatti Filho (PP/RS)  COVATTI FILHO
# 2   PL 1216/2015    Covatti Filho (PP/RS)  COVATTI FILHO
# 4   PL 6442/2016  Nilson Leitão (PSDB/MT)  NILSON LEITÃO
# 5  PDC 1300/2013  Nilson Leitão (PSDB/MT)  NILSON LEITÃO
# 6  PDC 1465/2014  Nilson Leitão (PSDB/MT)  NILSON LEITÃO
#
#                                               Ementa  \
# 1  Dispõe sobre a Política Nacional de Defensivos...
# 2  Regulamenta o artigo 231 da Constituição Feder...
# 4  Institui normas reguladoras do trabalho rural ...
# 5  Susta a aplicação da Instrução Normativa nº 01...
# 6  Susta a aplicação da Portaria Interministerial...
#
#                                              Assunto     Indicado_por  \
# 1  Cria outro nome para agrotóxicos e facilita a ...           Contag
# 2  Cria mais etapas para a demarcação de áreas in...             Apib
# 4  Altera regulamentação do trabalho rural e incl...     Contag e ISA
# ...

# %%
proj_contra = contra[contra.Qual_avaliacao == 'Desfavorável']

# %%
proj_contra.head(2)
# Out:
#         Projeto                   Nome          Autor  \
# 1  PL 3200/2015  Covatti Filho (PP/RS)  COVATTI FILHO
# 2  PL 1216/2015  Covatti Filho (PP/RS)  COVATTI FILHO
#
#                                               Ementa  \
# 1  Dispõe sobre a Política Nacional de Defensivos...
# 2  Regulamenta o artigo 231 da Constituição Feder...
#
#                                              Assunto Indicado_por  \
# 1  Cria outro nome para agrotóxicos e facilita a ...       Contag
# 2  Cria mais etapas para a demarcação de áreas in...         Apib
#
#   Quem_avaliou Qual_avaliacao             Estado         CPF Partido_eleicao  \
# 1       Contag   Desfavorável  RIO GRANDE DO SUL  1171688075              PP
# 2         Apib   Desfavorável  RIO GRANDE DO SUL  1171688075              PP
#
#   Nome_urna_tramitacao
# 1        COVATTI FILHO
# 2        COVATTI FILHO

# %%
proj_contra.Autor.value_counts()
# Out:
# JERÔNIMO GOERGEN            9
# LUIS CARLOS HEINZE          8
# NILSON LEITÃO               8
# VALDIR COLATTO              7
# JOSUÉ BENGTSON              5
# ADILTON SACHETTI            3
# ALCEU MOREIRA               3
# IRAJÁ ABREU                 3
# ROBERTO BALESTRA            2
# MARCOS MONTES               2
# EDUARDO DA FONTE            2
# DOMINGOS SÁVIO              2
# CARLOS BEZERRA              2
# AFONSO HAMM                 2
# VICENTINHO JÚNIOR           2
# COVATTI FILHO               2
# FLAVIANO MELO               1
# DILCEU SPERAFICO            1
# WELITON PRADO               1
# JOVAIR ARANTES              1
# CARLOS HENRIQUE GAGUIM      1
# BETO FARO                   1
# ALFREDO KAEFER              1
# MAX FILHO                   1
# SERGIO SOUZA                1
# LAERCIO OLIVEIRA            1
# CELSO MALDANER              1
# PROFESSOR VICTÓRIO GALLI    1
# DR. JORGE SILVA             1
# ANTONIO BALHMANN            1
# HEITOR SCHUCH               1
# ...

# %%
proj_contra.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 87 entries, 1 to 130
# Data columns (total 12 columns):
# Projeto                 87 non-null object
# Nome                    87 non-null object
# Autor                   87 non-null object
# Ementa                  34 non-null object
# Assunto                 87 non-null object
# Indicado_por            80 non-null object
# Quem_avaliou            87 non-null object
# Qual_avaliacao          87 non-null object
# Estado                  87 non-null object
# CPF                     87 non-null int64
# Partido_eleicao         87 non-null object
# Nome_urna_tramitacao    87 non-null object
# dtypes: int64(1), object(11)
# memory usage: 8.8+ KB

# %%
proj_contra.groupby('Autor')['Assunto'].value_counts()
# Out:
# Autor                     Assunto
# ADILTON SACHETTI          Autoriza aproveitamento da água em trechos das hidrovias dos rios Tapajós, Teles Pires e Juruena                                                                1
#                           Autoriza aproveitamento da água na hidrovia do rio Paraguai                                                                                                     1
#                           Autoriza obras para construção de hidrovias nos rios Tocantins (PA), Araguaia (GO) e das Mortes (MT), inclusive em terras indígenas                             1
# AFONSO HAMM               Determina que recomposição de áreas de preservação seja feita com plantio de árvores frutíferas; hoje é feita espécies nativas                                  1
#                           Libera o porte de arma para trabalhadores ou proprietários de áreas rurais maiores de 25 anos, nos limites da propriedade rural                                 1
# ...

# %%
pl = pd.merge(rural, proj_contra, on="Nome")

# %%
pl.head(3)
# Out:
#               Nome partido estado  mandatos  Situação  Evangélica  Ruralista  \
# 0  Giovani Cherini     PDT     RS       2.0       NaN         NaN        1.0
# 1    Alceu Moreira    PMDB     RS       2.0  Reeleito         1.0        1.0
# 2   Carlos Bezerra    PMDB     MT       4.0  Reeleito         NaN        1.0
#
#    Bala  Sindical  Direitos Humanos         ...                     Autor  \
# 0   NaN       NaN               NaN         ...           GIOVANI CHERINI
# 1   1.0       NaN               NaN         ...             ALCEU MOREIRA
# 2   NaN       NaN               NaN         ...            CARLOS BEZERRA
#
#    Ementa                                            Assunto  Indicado_por  \
# 0     NaN  Anula efeitos de portaria do Ministério do Tra...           ISA
# 1     NaN  Anula portaria do Ministério do Meio Ambiente ...           ISA
# 2     NaN  Proposta dificulta desapropriação de terras pa...     ISA e CPT
#
# ...

# %%
pl.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 22 entries, 0 to 21
# Data columns (total 28 columns):
# Nome                         22 non-null object
# partido                      22 non-null object
# estado                       22 non-null object
# mandatos                     22 non-null float64
# Situação                     20 non-null object
# Evangélica                   11 non-null float64
# Ruralista                    22 non-null float64
# Bala                         1 non-null float64
# Sindical                     1 non-null float64
# Direitos Humanos             0 non-null float64
# Mineração                    0 non-null float64
# Empresarial                  16 non-null float64
# Parentes                     14 non-null float64
# Saúde                        0 non-null float64
# Bola                         1 non-null float64
# Empreiteiras/construtoras    7 non-null float64
# Total de bancadas            22 non-null float64
# ...

# %%
pl.Quem_avaliou.value_counts()
# Out:
# ISA          20
# ISA e CPT     2
# Name: Quem_avaliou, dtype: int64

# %%
pl[pl.Assunto == 'Determina que recomposição de áreas de preservação seja feita com plantio de árvores frutíferas; hoje é feita espécies nativas']
# Out:
#           Nome partido estado  mandatos  Situação  Evangélica  Ruralista  \
# 8  Afonso Hamm      PP     RS       4.0  Reeleito         NaN        1.0
#
#    Bala  Sindical  Direitos Humanos         ...                 Autor  Ementa  \
# 8   NaN       NaN               NaN         ...           AFONSO HAMM     NaN
#
#                                              Assunto  Indicado_por  \
# 8  Determina que recomposição de áreas de preserv...           ISA
#
#    Quem_avaliou  Qual_avaliacao             Estado          CPF  \
# 8           ISA    Desfavorável  RIO GRANDE DO SUL  37040642034
#
#   Partido_eleicao Nome_urna_tramitacao
# 8              PP          AFONSO HAMM
#
# [1 rows x 28 columns]

# %%
pl[pl.Assunto == 'Anula resolução do Conama que prevê a proteção de área de preservação permanente no entorno de reservatórios']
# Out:
#               Nome partido estado  mandatos  Situação  Evangélica  Ruralista  \
# 19  Josué Bengtson     PTB     PA       4.0  Reeleito         1.0        1.0
#
#     Bala  Sindical  Direitos Humanos         ...                    Autor  \
# 19   NaN       NaN               NaN         ...           JOSUÉ BENGTSON
#
#     Ementa                                            Assunto  Indicado_por  \
# 19     NaN  Anula resolução do Conama que prevê a proteção...           ISA
#
#     Quem_avaliou  Qual_avaliacao  Estado         CPF Partido_eleicao  \
# 19           ISA    Desfavorável    PARÁ  9673504768             PTB
#
#    Nome_urna_tramitacao
# 19       JOSUÉ BENGTSON
#
# [1 rows x 28 columns]

# %%
pl[pl.Assunto == 'Proposta dificulta desapropriação de terras para reforma agrária']
# Out:
#              Nome partido estado  mandatos  Situação  Evangélica  Ruralista  \
# 2  Carlos Bezerra    PMDB     MT       4.0  Reeleito         NaN        1.0
#
#    Bala  Sindical  Direitos Humanos         ...                    Autor  \
# 2   NaN       NaN               NaN         ...           CARLOS BEZERRA
#
#    Ementa                                            Assunto  Indicado_por  \
# 2     NaN  Proposta dificulta desapropriação de terras pa...     ISA e CPT
#
#    Quem_avaliou  Qual_avaliacao       Estado        CPF Partido_eleicao  \
# 2     ISA e CPT    Desfavorável  MATO GROSSO  834939134            PMDB
#
#   Nome_urna_tramitacao
# 2       CARLOS BEZERRA
#
# [1 rows x 28 columns]

# %%
pl[pl.Assunto == 'Dispensa licença ambiental para agropecuária em áreas degradadas']
# Out:
#            Nome partido estado  mandatos  Situação  Evangélica  Ruralista  \
# 14  Irajá Abreu     PSD     TO       2.0  Reeleito         NaN        1.0
#
#     Bala  Sindical  Direitos Humanos         ...                 Autor  \
# 14   NaN       NaN               NaN         ...           IRAJÁ ABREU
#
#     Ementa                                            Assunto  Indicado_por  \
# 14     NaN  Dispensa licença ambiental para agropecuária e...           ISA
#
#     Quem_avaliou  Qual_avaliacao     Estado          CPF Partido_eleicao  \
# 14           ISA    Desfavorável  TOCANTINS  60507306104             PSD
#
#    Nome_urna_tramitacao
# 14          IRAJÁ ABREU
#
# [1 rows x 28 columns]

# %%
pl[pl.Assunto == 'Susta portaria que proíbe coleta, corte e comercialização de espécies da flora ameaçadas de extinção']
# Out:
#              Nome partido estado  mandatos  Situação  Evangélica  Ruralista  \
# 16  Nilson Leitão    PSDB     MT       2.0  Reeleito         NaN        1.0
#
#     Bala  Sindical  Direitos Humanos         ...                   Autor  \
# 16   NaN       NaN               NaN         ...           NILSON LEITÃO
#
#     Ementa                                            Assunto  Indicado_por  \
# 16     NaN  Susta portaria que proíbe coleta, corte e come...           ISA
#
#     Quem_avaliou  Qual_avaliacao       Estado          CPF Partido_eleicao  \
# 16           ISA    Desfavorável  MATO GROSSO  34577521172            PSDB
#
#    Nome_urna_tramitacao
# 16        NILSON LEITÃO
#
# [1 rows x 28 columns]

# %%
pl[pl.Assunto == 'Anula portaria do Ministério do Meio Ambiente que proíbe pesca de 475 espécies ameaçadas de extinção']
# Out:
#             Nome partido estado  mandatos  Situação  Evangélica  Ruralista  \
# 1  Alceu Moreira    PMDB     RS       2.0  Reeleito         1.0        1.0
#
#    Bala  Sindical  Direitos Humanos         ...                   Autor  \
# 1   1.0       NaN               NaN         ...           ALCEU MOREIRA
#
#    Ementa                                            Assunto  Indicado_por  \
# 1     NaN  Anula portaria do Ministério do Meio Ambiente ...           ISA
#
#    Quem_avaliou  Qual_avaliacao             Estado          CPF  \
# 1           ISA    Desfavorável  RIO GRANDE DO SUL  17968496004
#
#   Partido_eleicao Nome_urna_tramitacao
# 1            PMDB        ALCEU MOREIRA
#
# [1 rows x 28 columns]

# %%
pl.Autor.value_counts()
# Out:
# JOSUÉ BENGTSON        3
# VALDIR COLATTO        2
# CARLOS BEZERRA        2
# IRAJÁ ABREU           1
# NILSON LEITÃO         1
# TONINHO PINHEIRO      1
# TEREZA CRISTINA       1
# AFONSO HAMM           1
# SERGIO SOUZA          1
# JOVAIR ARANTES        1
# ALFREDO KAEFER        1
# HEITOR SCHUCH         1
# LAERCIO OLIVEIRA      1
# CELSO MALDANER        1
# ALCEU MOREIRA         1
# ROBERTO BALESTRA      1
# GIOVANI CHERINI       1
# LUIS CARLOS HEINZE    1
# Name: Autor, dtype: int64

# %%
pl.groupby('Autor')['Assunto'].value_counts()
# Out:
# Autor               Assunto
# AFONSO HAMM         Determina que recomposição de áreas de preservação seja feita com plantio de árvores frutíferas; hoje é feita espécies nativas                              1
# ALCEU MOREIRA       Anula portaria do Ministério do Meio Ambiente que proíbe pesca de 475 espécies ameaçadas de extinção                                                        1
# ALFREDO KAEFER      Determina que ANP regule e fiscalize exploração de xisto betuminoso                                                                                         1
# CARLOS BEZERRA      Classifica cavernas como áreas de proteção e patrimônio nacional                                                                                            1
#                     Proposta dificulta desapropriação de terras para reforma agrária                                                                                            1
# ...

# %% [markdown]
# #### Cruzando com dados de deputados multados pelo Ibama; deputados com empresas rurais e doações de empresas flagradas por trabalho escravo.
# #### Fonte.: https://ruralometro.reporterbrasil.org.br/metodologia#download

# %%
ibama = pd.read_csv('multados_ibama.csv')

# %%
ibama
# Out:
#                       deputado_nome Entidade_documento_original  \
# 0   Carlos Cesar Correia de Messias              508.720.607-72
# 1             Irajá Silvestre Filho              605.073.061-04
# 2             Irajá Silvestre Filho              605.073.061-04
# 3             Irajá Silvestre Filho              605.073.061-04
# 4                  Jose Alves Rocha              047.891.135-15
# 5          José Maria Macedo Júnior              197.057.864-53
# 6          José Maria Macedo Júnior              197.057.864-53
# 7          José Maria Macedo Júnior              197.057.864-53
# 8          José Maria Macedo Júnior              197.057.864-53
# 9          José Maria Macedo Júnior              197.057.864-53
# 10         José Maria Macedo Júnior              197.057.864-53
# 11         José Maria Macedo Júnior              197.057.864-53
# 12            Luiz Gonzaga Patriota              019.609.704-53
#
# ...

# %%
ibama.deputado_nome.value_counts()
# Out:
# José Maria Macedo Júnior           7
# Irajá Silvestre Filho              3
# Luiz Gonzaga Patriota              1
# Jose Alves Rocha                   1
# Carlos Cesar Correia de Messias    1
# Name: deputado_nome, dtype: int64

# %%
ibama.Valor_multa.max()
# Out:
# 150.0

# %%
ibama.groupby('deputado_nome')['Valor_multa'].sum()
# Out:
# deputado_nome
# Carlos Cesar Correia de Messias      6.0
# Irajá Silvestre Filho              130.0
# Jose Alves Rocha                     5.0
# José Maria Macedo Júnior           280.0
# Luiz Gonzaga Patriota               11.0
# Name: Valor_multa, dtype: float64

# %%
escravo = pd.read_csv('dep_emp_escravo.csv')

# %%
escravo.politico_nome_urna
# Out:
# 0          BETO MANSUR
# 1          BETO MANSUR
# 2    LEONARDO PICCIANI
# Name: politico_nome_urna, dtype: object

# %%
dep_rural = pd.read_csv('empresas_rurais_dep.csv')

# %%
dep_rural.head()
# Out:
#    uf                        Nome           cpf nome_urna partido_eleicao  \
# 0  PA  JOSE BENITO PRIANTE JUNIOR  1.729362e+10   PRIANTE            PMDB
# 1  PA  JOSE BENITO PRIANTE JUNIOR  1.729362e+10   PRIANTE            PMDB
# 2  PA  JOSE BENITO PRIANTE JUNIOR  1.729362e+10   PRIANTE            PMDB
# 3  PA  JOSE BENITO PRIANTE JUNIOR  1.729362e+10   PRIANTE            PMDB
# 4  PA  JOSE BENITO PRIANTE JUNIOR  1.729362e+10   PRIANTE            PMDB
#
#              cnpj                                 empresa estado  \
# 0   4322499000104    AGROPECUARIA RIO DA PRATA LTDA - EPP   Pará
# 1   4322499000104    AGROPECUARIA RIO DA PRATA LTDA - EPP   Pará
# 2   4322499000104    AGROPECUARIA RIO DA PRATA LTDA - EPP   Pará
# 3  20008829000148  AGROINDUSTRIAL ACAI DA PRATA LTDA - ME   Pará
# 4  20008829000148  AGROINDUSTRIAL ACAI DA PRATA LTDA - ME   Pará
#
#                           socios situacao_empresa                cidade  \
# ...

# %%
dep_rural.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 167 entries, 0 to 166
# Data columns (total 16 columns):
# uf                         165 non-null object
# Nome                       167 non-null object
# cpf                        165 non-null float64
# nome_urna                  167 non-null object
# partido_eleicao            165 non-null object
# cnpj                       167 non-null int64
# empresa                    167 non-null object
# estado                     167 non-null object
# socios                     167 non-null object
# situacao_empresa           167 non-null object
# cidade                     167 non-null object
# cnae_principal             167 non-null object
# propriedade                167 non-null object
# capital_social             167 non-null object
# agricola_ou_relacionada    167 non-null object
# cnpj_raiz                  167 non-null int64
# dtypes: float64(1), int64(2), object(13)
# memory usage: 21.0+ KB

# %%
dep_rural.Nome.value_counts()
# Out:
# ANIBAL FERREIRA GOMES                    10
# LUIS CARLOS HEINZE                        9
# NEWTON CARDOSO JUNIOR                     8
# PAULO SALIM MALUF                         7
# IRAJA SILVESTRE FILHO                     7
# CARLOS DO CARMO ANDRADE MELLES            6
# CLAUDIO CAJADO SAMPAIO                    6
# MARCELO COSTA E CASTRO                    5
# JOSE BENITO PRIANTE JUNIOR                5
# JOSE ORCIRIO MIRANDA DOS SANTOS           5
# GIUSEPPE VECCI                            5
# JACOB ALFREDO STOFFELS KAEFER             5
# LEONARDO CARNEIRO MONTEIRO PICCIANI       5
# LUIZ HILOSHI NISHIMORI                    5
# MARIO LUCIO HERINGER                      5
# VALDIR LUIZ ROSSONI                       5
# EDMAR DE SOUZA ARRUDA                     4
# NELSON MARQUEZELLI                        4
# ARTHUR DE OLIVEIRA MAIA DA SILVA          4
# PAULO ROBERTO GOMES MANSUR                4
# MARINALDO ROSENDO DE ALBUQUERQUE          4
# ...

# %%
sujas = pd.read_csv('doacoes_escravo.csv')

# %%
sujas.head()
# Out:
#    uf             cargo                               Nome          cpf  \
# 0  MG  Deputado Federal      DOMINGOS SAVIO CAMPOS RESENDE  22275150668
# 1  BA  Deputado Federal                LUIZ CARLOS CAETANO   7409419504
# 2  BA  Deputado Federal       MOEMA ISABEL PASSOS GRAMACHO  13339982520
# 3  BA  Deputado Federal  NELSON VICENTE PORTELA PELLEGRINO  24289612504
# 4  BA  Deputado Federal          JOSÉ CARLOS ALELUIA COSTA   1782037500
#
#    cpf_cnpj_doador                          nome_doador  valor  \
# 0   23998438000106  CCM - CONSTRUTORA CENTRO MINAS LTDA  15000
# 1   16365025000129         GRAFICO EMPREENDIMENTOS LTDA   6000
# 2   16365025000129                   GRAFICO ENGENHARIA  10000
# 3   16365025000129         GRAFICO EMPREENDIMENTOS LTDA   3000
# 4   16365025000129        GRAFICA EMPREENDIMENTOS LTDA.   1000
#
#   cpf_cnpj_doador_originario nome_doador_originario tipo_doacao
# 0                      #NULO                  #NULO      direta
# ...

# %%
sujas.groupby('Nome')['nome_doador'].value_counts()
# Out:
# Nome                                   nome_doador
# AFONSO BANDEIRA FLORENCE               SERTENGE S/A                                                     1
# AGUINALDO VELLOSO BORGES RIBEIRO       Direção Estadual/Distrital                                       2
# ALFREDO PEREIRA DO NASCIMENTO          Direção Estadual/Distrital                                       1
# ANDRÉ LUIS CARVALHO RIBEIRO            FRANCISCO DANTAS RIBEIRO FILHO                                   1
# ANTONIO SERGIO ALVES VIDIGAL           MRV ENGENHARIA E PARTICPAÇÕES SA                                 1
# ARLINDO CHIGNALIA JUNIOR               Direção Nacional                                                 1
# ARTHUR DE OLIVEIRA MAIA DA SILVA       SINOBRAS - SIDERURGICA NORTE BRASIL - S.A.                       1
# ATILA FREITAS LIRA                     CELSO DE SOUSA MENDES FILHO                                      1
# ...

# %%
sujas.Nome.max()
# Out:
# 'WELINGTON COIMBRA'

# %%
sujas.Nome.min()
# Out:
# 'AFONSO BANDEIRA FLORENCE'

# %%
sujas.nome_doador.max()
# Out:
# 'TRATENGE ENGENHARIA LTDA'

# %%
sujas.nome_doador.value_counts()
# Out:
# ELEICAO 2014 PAULO ANTONIO SKAF GOVERNADOR                       8
# PAULO ANTONIO SKAF                                               8
# ELEIÇÃO 2014 - PAULO ANTONIO SKAF GOVERNADOR                     8
# ELEIÇÃO 2014 PAULO JOSE CARLOS GUEDES                            6
# ELEICAO 2014 DURVAL ANGELO ANDRADE DEPUTADO ESTADUAL             6
# Direção Estadual/Distrital                                       6
# CONSTRUTORA JUREMA LTDA                                          4
# Direção Nacional                                                 4
# SUCOCITRICO CUTRALE LTDA                                         3
# SIDERURGICA NORTE BRASIL S.A                                     3
# GRAFICO EMPREENDIMENTOS LTDA                                     3
# Comitê Financeiro Único                                          3
# ELEIÇÃO 2014 PAULO ROBERTO LAMAC JUNIOR                          3
# SERTENGE S/A                                                     3
# ...
